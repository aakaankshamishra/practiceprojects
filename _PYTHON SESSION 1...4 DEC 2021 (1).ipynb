# %% [markdown]
# # welcome to python

# %% [markdown]
# learning python basics

# %%
1+1
# Out:
# 2

# %%
2-1
# Out:
# 1

# %%
3*2
# Out:
# 6

# %%
10/2
# Out:
# 5.0

# %%
10//2
# Out:
# 5

# %% [markdown]
# floor division

# %%
10%2
# Out:
# 0

# %%
11%2
# Out:
# 1

# %%
17%3
# Out:
# 2

# %% [markdown]
# remainder

# %%
2**2
# Out:
# 4

# %% [markdown]
# power

# %%
2**8
# Out:
# 256

# %%
2**3
# Out:
# 8

# %% [markdown]
# working with variables

# %%
a=2

# %%
a
# Out:
# 2

# %%
b=1

# %%
b
# Out:
# 1

# %%
a+b
# Out:
# 3

# %%
a-b
# Out:
# 1

# %%
c=a+b

# %%
c
# Out:
# 3

# %%
d=a-b

# %%
d
# Out:
# 1

# %% [markdown]
# mul is a variable, means we can give any name to variable

# %%
mul=a*b

# %%
mul
# Out:
# 2

# %% [markdown]
# area of rectangle

# %%
length=50
breadth=15
area=length*breadth
area
# Out:
# 750

# %% [markdown]
# perimeter

# %%
length=52
breadth=45
peri=2*(length+breadth)
peri
# Out:
# 194

# %%
c
# Out:
# 3

# %%
print(c)
# Out:
# 3

# %%
print("c=")
# Out:
# c=

# %%
print("c=",c)
# Out:
# c= 3

# %%
city="Delhi"

# %%
city
# Out:
# 'Delhi'

# %%
country='India'

# %%
country
# Out:
# 'India'

# %%
print("c=",c)
# Out:
# c= 3

# %% [markdown]
# area of rectangle

# %%
length=50
breadth=15
area=length*breadth
print("area of rectangle",area)
# Out:
# area of rectangle 750

# %%
length=50
breadth=15
area=length*breadth
print("area of rectangle=",area)
print("area of rectangle with length",length,"and breadth=",breadth,"=",area)
# Out:
# area of rectangle= 750
# area of rectangle with length 50 and breadth= 15 = 750

# %% [markdown]
# perimeter

# %%
length=45
breadth=50
peri=2*(length+breadth)
print("perimeter of rectangle=",peri)
# Out:
# perimeter of rectangle= 190

# %% [markdown]
# area of circle

# %%
#Area of circle  ==== pi*(radius**2)
pi=3.14
radius=15
area_of_circle=pi*(radius**2)
print("Area of circle=",area_of_circle)
print("Area of circle with radius=",radius,"is",area_of_circle)
# Out:
# Area of circle= 706.5
# Area of circle with radius= 15 is 706.5

# %%
#circumference of circle ====2*pi*r
pi=3.14
radius=15
circumference_of_circle=2*pi*radius
print("circumference of circle=",circumference_of_circle)
print("circumference of circle with radius=",radius,"is",circumference_of_circle)
# Out:
# circumference of circle= 94.2
# circumference of circle with radius= 15 is 94.2

# %%
country=input("enter any country name")
# Out:
# enter any country nameGermany

# %%
country
# Out:
# 'Germany'

# %%
a=input("enter any number")
# Out:
# enter any number45

# %%
a
# Out:
# '45'

# %% [markdown]
# type casting

# %%
type(28)
# Out:
# int

# %%
type(56)
# Out:
# int

# %%
type(900)
# Out:
# int

# %%
type(666.56)
# Out:
# float

# %%
type('india')
# Out:
# str

# %%
h=98

# %%
type(h)
# Out:
# int

# %%
float(h)
# Out:
# 98.0

# %%
m=float(h)

# %%
m
# Out:
# 98.0

# %%
type(m)
# Out:
# float

# %%
fm=6545.5

# %%
fm
# Out:
# 6545.5

# %%
type(fm)
# Out:
# float

# %%
j=int(fm)

# %%
j
# Out:
# 6545

# %%
type(j)
# Out:
# int

# %%
j
# Out:
# 6545

# %% [markdown]
# length

# %%
len("ABCD")
# Out:
# 4

# %%
len("XYZ")
# Out:
# 3

# %%
len("LONDON")
# Out:
# 6

# %%
CITY="BANGLORE"

# %%
CITY
# Out:
# 'BANGLORE'

# %%
len("city")
# Out:
# 4

# %%
len("banglore")
# Out:
# 8

# %%
len(city)
# Out:
# 8
