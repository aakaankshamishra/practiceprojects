# %%
fadd(20,20)
# Out:
# 40

# %%
fadd(100,50)
# Out:
# 150

# %%
fadd(1,6,9)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9244/1048378073.py in <module>
# ----> 1 fadd(1,6,9)
#
# TypeError: fadd() takes 2 positional arguments but 3 were given

# %%
fadd(2,6)
# Out:
# 8

# %%
def fsubtract(a,b):
    c=a-b
    print(c)

# %%
fsubtract(40,5)
# Out:
# 35

# %%
fsubtract(4,20)
# Out:
# -16

# %%
def fmultiply(x,y):
    z=x*y
    print(z)

# %%
fmultiply (4,5)
# Out:
# 20

# %%
fmultiply(7,8)
# Out:
# 56

# %%
def faddition(x,y,z):
    add=x+y+z
    print(add)

# %%
faddition(5,6,2)
# Out:
# 13

# %%
faddition(10,20,60)
# Out:
# 90

# %%
def areaofrect(l,b):
    area=l*b
    print("area of rectangle=",area)

# %%
l=int(input("enter length"))
b=int(input("enter breadth"))
print("length=",l)
print("breadth=",b)
areaofrect(l,b)
# Out:
# enter length12
# enter breadth56
# length= 12
# breadth= 56
# area of rectangle= 672

# %%
l=int(input("enter length"))
b=int(input("enter breadth"))
print("length=",l)
print("breadth=",b)
areaofrect(l,b)
# Out:
# enter length56
# enter breadth23
# length= 56
# breadth= 23
# area of rectangle= 1288

# %%
def area_of_circle(radius):
    pi=3.14
    area=pi*(radius**2)
    print("area of circle=",area)

# %%
radius=int(input("enter radius"))
area_of_circle(radius)
# Out:
# enter radius12332
# area of circle= 477525623.36

# %%
pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9244/3440806613.py in <module>
# ----> 1 pi
#
# NameError: name 'pi' is not defined

# %%
radius
# Out:
# 12332

# %%
l
# Out:
# 56

# %%
b
# Out:
# 23

# %% [markdown]
# all these are global variable

# %%
c
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9244/3235490055.py in <module>
# ----> 1 c
#
# NameError: name 'c' is not defined

# %% [markdown]
# we can not access c as it is a local varible

# %%
def funcadd():
    a=10
    b=20
    c=a+b
    return c

# %%
val=funcadd()
print(val)
# Out:
# 30

# %%
def function_multiply(a,b):
    c=a*b
    return c

# %%
myval=function_multiply(80,90)
myval
# Out:
# 7200

# %%
def areacircle(val):
    ar=3.14*(val**2)
    print("area of circle",ar)

# %%
#calling a function
areacircle(val)
# Out:
# area of circle 2826.0

# %%
def arearect():
    length=10
    breadth=56
    return length*breadth

# %%
arearect()
# Out:
# 560
