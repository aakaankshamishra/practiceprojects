# %%
import pandas as pd
df=pd.read_csv('student_marks.csv')
df.head()
# Out:
#   Unnamed: 0 Gender         DOB  Maths  Physics  Chemistry  English  Biology  \
# 0       John      M  05-04-1988     55       45         56       87       21
# 1     Suresh      M  04-05-1987     75       96         78       64       90
# 2     Ramesh      M  25-05-1989     25       54         89       76       95
# 3    Jessica      F  12-08-1990     78       96         86       63       54
# 4   Jennifer      F  02-09-1989     58       96         78       46       96
#
#    Economics  History  Civics
# 0         52       89      65
# 1         61       58       2
# 2         87       56      74
# 3         89       75      45
# 4         77       83      53

# %%
df['Maths'].mean()
# Out:
# 59.6

# %%
df['English'].mean()
# Out:
# 69.7

# %%
df['Chemistry'].mean()
# Out:
# 75.3

# %%
df['Maths'].median()
# Out:
# 55.0

# %%
df['Civics'].median()
# Out:
# 63.0

# %%
df['Maths'].median()
# Out:
# 55.0

# %%
df['Maths'].mode()
# Out:
# 0    55
# dtype: int64

# %%
df['Physics'].mode()
# Out:
# 0    96
# dtype: int64

# %% [markdown]
# # PERCENTILE

# %%
import numpy as np
a=np.array([1,3,3,4,5,6,6,7,8,8])
np.percentile(a,100)
# Out:
# 8.0

# %%
np.percentile(a,50)
# Out:
# 5.5

# %%
np.percentile(a,25)
# Out:
# 3.25

# %% [markdown]
# # SCIPY LIBRARY GIVES ALL STATISTICS FUNCTION

# %%
import scipy
import numpy as np 
import warnings
warnings.filterwarnings("ignore")

scipy.__version__
# Out:
# '1.7.1'

# %%
a=np.array([[3,7,5],[8,4,3],[2,4,9]])
a
# Out:
# array([[3, 7, 5],
#        [8, 4, 3],
#        [2, 4, 9]])

# %%
print(scipy.mean(a))
# Out:
# 5.0

# %%
print(scipy.median(a))
# Out:
# 4.0

# %%
print(round(scipy.var(a),2))
# Out:
# 5.33

# %%
print(round(scipy.std(a),2))
# Out:
# 2.31

# %%
#st.mode

# %%
import scipy.stats as st
p=np.array([5,8,9,5,6,5,10,14])
st.mode(p)
# Out:
# ModeResult(mode=array([5]), count=array([3]))

# %%
b=np.array([[1,3,4,2,2,7],
            [5,2,2,1,4,1],
            [3,3,2,2,1,1]])

# %%
b
# Out:
# array([[1, 3, 4, 2, 2, 7],
#        [5, 2, 2, 1, 4, 1],
#        [3, 3, 2, 2, 1, 1]])

# %%
m=st.mode(b)

# %%
m
# Out:
# ModeResult(mode=array([[1, 3, 2, 2, 1, 1]]), count=array([[1, 2, 2, 2, 1, 2]]))

# %%
df.describe()
# Out:
#            Maths    Physics  Chemistry    English    Biology  Economics  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   59.600000  72.300000  75.300000  69.700000  64.700000  72.700000
# std    19.460501  20.661559  14.000397  14.453373  26.998148  14.629119
# min    25.000000  45.000000  52.000000  46.000000  21.000000  52.000000
# 25%    54.250000  56.250000  65.000000  59.250000  54.250000  58.750000
# 50%    55.000000  70.000000  78.000000  69.500000  66.500000  76.000000
# 75%    70.750000  93.750000  86.750000  81.250000  87.000000  86.000000
# max    96.000000  96.000000  89.000000  89.000000  96.000000  89.000000
#
#          History   Civics
# count  10.000000  10.0000
# mean   69.700000  60.5000
# std    14.453373  25.3432
# min    46.000000   2.0000
# 25%    59.250000  52.2500
# 50%    69.500000  63.0000
# 75%    81.250000  76.2500
# max    89.000000  89.0000

# %%
import scipy
from scipy import stats
from scipy.stats import percentileofscore

# %%
percentileofscore(df['Maths'],25)
# Out:
# 10.0

# %%
percentileofscore(df['Maths'],60)
# Out:
# 70.0

# %%
percentileofscore(df['English'],75)
# Out:
# 60.0

# %%
percentileofscore(df['Biology'],60)
# Out:
# 50.0

# %%
max_m=df['Maths'].max()
max_m
# Out:
# 96

# %%
min_m=df['Maths'].min()
min_m
# Out:
# 25

# %%
r=max_m-min_m
r
# Out:
# 71

# %% [markdown]
# # SPREAD OF DATA

# %% [markdown]
# IQR -interquartile = Q3-Q1

# %%
q1=df['Maths'].quantile(.25)
q1
# Out:
# 54.25

# %%
q3=df['Maths'].quantile(0.75)
q3
# Out:
# 70.75

# %%
IQR=q3-q1
IQR
# Out:
# 16.5

# %% [markdown]
# # SCIPY

# %%
from scipy.stats import zscore

# %%
zscore([56,34,21,33])
# Out:
# array([ 1.58361516, -0.15836152, -1.18771137, -0.23754227])

# %%
df.iloc[:,3:-1]
# Out:
#    Maths  Physics  Chemistry  English  Biology  Economics  History
# 0     55       45         56       87       21         52       89
# 1     75       96         78       64       90         61       58
# 2     25       54         89       76       95         87       56
# 3     78       96         86       63       54         89       75
# 4     58       96         78       46       96         77       83
# 5     45       87         52       89       55         89       87
# 6     55       64         61       58       75         58       64
# 7     54       76         87       56       25         56       76
# 8     55       63         89       75       78         75       63
# 9     96       46         77       83       58         83       46

# %%
 df.iloc[:,3:10]
# Out:
#    Maths  Physics  Chemistry  English  Biology  Economics  History
# 0     55       45         56       87       21         52       89
# 1     75       96         78       64       90         61       58
# 2     25       54         89       76       95         87       56
# 3     78       96         86       63       54         89       75
# 4     58       96         78       46       96         77       83
# 5     45       87         52       89       55         89       87
# 6     55       64         61       58       75         58       64
# 7     54       76         87       56       25         56       76
# 8     55       63         89       75       78         75       63
# 9     96       46         77       83       58         83       46

# %%
#correlation

dfc=df.corr()
dfc
# Out:
#               Maths   Physics  Chemistry   English   Biology  Economics  \
# Maths      1.000000  0.113354   0.076751 -0.064074 -0.146598   0.000312
# Physics    0.113354  1.000000   0.117192 -0.562608  0.279638   0.191851
# Chemistry  0.076751  0.117192   1.000000 -0.409680  0.318032   0.235390
# English   -0.064074 -0.562608  -0.409680  1.000000 -0.330844   0.237577
# Biology   -0.146598  0.279638   0.318032 -0.330844  1.000000   0.370531
# Economics  0.000312  0.191851   0.235390  0.237577  0.370531   1.000000
# History   -0.320846  0.334082  -0.482710 -0.038775 -0.456131  -0.164953
# Civics    -0.274629 -0.643266   0.210908  0.186705 -0.330060   0.043905
#
#             History    Civics
# Maths     -0.320846 -0.274629
# Physics    0.334082 -0.643266
# Chemistry -0.482710  0.210908
# English   -0.038775  0.186705
# Biology   -0.456131 -0.330060
# Economics -0.164953  0.043905
# History    1.000000 -0.048686
# Civics    -0.048686  1.000000

# %%
import seaborn as sns
sns.heatmap(dfc)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(dfc,cmap="Blues",annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # cateogorical variable test of independence----chi square test

# %%
#checking the chi square test

# %%
import numpy as np
import pandas as pd
import scipy.stats as stats
ds=pd.read_csv("role_website.csv")

# %%
df=pd.DataFrame(ds)
df
# Out:
#        role   website
# 0   teacher  linkedin
# 1   teacher  linkedin
# 2   student  facebook
# 3   student  facebook
# 4   teacher  linkedin
# 5   student  facebook
# 6   student  facebook
# 7   teacher  linkedin
# 8   teacher  linkedin
# 9   teacher  facebook
# 10  teacher  facebook
# 11  teacher  facebook
# 12  teacher  facebook
# 13  student  facebook
# 14  student  linkedin
# 15  student  facebook
# 16  teacher  linkedin
# 17  student  linkedin
# 18  student  facebook
# 19  student  facebook
# 20  student  linkedin
# 21  teacher  facebook
# 22  teacher  linkedin
# 23  teacher  linkedin
# 24  teacher  linkedin
# 25  teacher  linkedin
# 26  teacher  linkedin
# 27  teacher  facebook
# 28  teacher  linkedin
# 29  teacher  linkedin
# 30  teacher  linkedin
# 31  teacher  linkedin
# 32  student  facebook
# 33  student  facebook

# %%
df.describe()
# Out:
#            role   website
# count        34        34
# unique        2         2
# top     teacher  linkedin
# freq         21        18

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   role     34 non-null     object
#  1   website  34 non-null     object
# dtypes: object(2)
# memory usage: 672.0+ bytes

# %%
df.dtypes
# Out:
# role       object
# website    object
# dtype: object

# %%
#create contigency table
df_crosstab = pd.crosstab(df['role'],df['website'],margins = True)
print(df_crosstab)
# Out:
# website  facebook  linkedin  All
# role
# student        10         3   13
# teacher         6        15   21
# All            16        18   34

# %%
df_crosstab.columns=["facebook","linkedin","row_totals"]
df_crosstab.index=["student","teacher","col_totals"]
df_crosstab
# Out:
#             facebook  linkedin  row_totals
# student           10         3          13
# teacher            6        15          21
# col_totals        16        18          34

# %%
#get the observed table
observed=df_crosstab.iloc[0:2,0:2]

# %%
observed
# Out:
#          facebook  linkedin
# student        10         3
# teacher         6        15

# %%
"""methodology2:calculate chi square using scipy.stat library"""

chi2,p,dof,expected = stats.chi2_contigency(observed=observed)
print("chi square test=",chi2)
print("p-value=",p)
print("dof=",dof)
print("expected=",expected)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_5828/1749602488.py in <module>
#       1 """methodology2:calculate chi square using scipy.stat library"""
#       2
# ----> 3 chi2,p,dof,expected = stats.chi2_contigency(observed=observed)
#       4 print("chi square test=",chi2)
#       5 print("p-value=",p)
#
# AttributeError: module 'scipy.stats' has no attribute 'chi2_contigency'
