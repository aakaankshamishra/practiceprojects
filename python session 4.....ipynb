# %% [markdown]
# # DICTIONARY

# %%
dict2={'name':'zara','age':7,'class':'first'}

# %%
dict2
# Out:
# {'name': 'zara', 'age': 7, 'class': 'first'}

# %%
dict2['name']
# Out:
# 'zara'

# %%
print(dict2['age'])
# Out:
# 7

# %%
dict2['age']=10

# %%
dict2
# Out:
# {'name': 'zara', 'age': 10, 'class': 'first'}

# %%
print("dict['name']:",dict2['name'])
# Out:
# dict['name']: zara

# %%
len(dict2)
# Out:
# 3

# %%
dict2.keys()
# Out:
# dict_keys(['name', 'age', 'class'])

# %%
dict2.values()
# Out:
# dict_values(['zara', 10, 'first'])

# %%
dict2.items()
# Out:
# dict_items([('name', 'zara'), ('age', 10), ('class', 'first')])

# %%
#Adding a new key value pair
dict2.update({'fee':5000})

# %%
dict2
# Out:
# {'name': 'zara', 'age': 10, 'class': 'first', 'fee': 5000}

# %%
#updating existing key's value
dict2['fee']=9500
print(dict2)
# Out:
# {'name': 'zara', 'age': 10, 'class': 'first', 'fee': 9500}

# %% [markdown]
# make a dictonary naming colordict with key-value pair
# rock:brown
# trees:green
# apple:red
# banana:yellow
# and then print it

# %%
colordict={'rock':'brown','trees':'green','apple':'red','banana':'yellow'}
print(colordict)
# Out:
# {'rock': 'brown', 'trees': 'green', 'apple': 'red', 'banana': 'yellow'}

# %% [markdown]
# # ENHANCED OPERTION IN DICTIONARY

# %%
#dictionary with integer keys:
intdict={10:"c++",20:"java",30:"python",40:"ruby"}

# %%
intdict.keys()
# Out:
# dict_keys([10, 20, 30, 40])

# %%
intdict.values()
# Out:
# dict_values(['c++', 'java', 'python', 'ruby'])

# %%
intdict.items()
# Out:
# dict_items([(10, 'c++'), (20, 'java'), (30, 'python'), (40, 'ruby')])

# %%
#adding a new key to a dictionary
intdict.update({50:'rails'})

# %%
intdict
# Out:
# {10: 'c++', 20: 'java', 30: 'python', 40: 'ruby', 50: 'rails'}

# %%
#updating a value in a given key
intdict[40]='csharp'

# %%
intdict
# Out:
# {10: 'c++', 20: 'java', 40: 'csharp', 50: 'rails'}

# %%
#delete a key
del intdict[50]

# %%
intdict
# Out:
# {10: 'c++', 20: 'java', 40: 'csharp'}

# %%
#delete with pop
intdict.pop(20)
# Out:
# 'java'

# %%
intdict
# Out:
# {10: 'c++', 40: 'csharp'}

# %%
intdict.items()
# Out:
# dict_items([(10, 'c++'), (40, 'csharp')])

# %%
dict3={'id':[1,2,3],'name':['jack','john','james'],'grade':['first','second','third']}
dict3
# Out:
# {'id': [1, 2, 3],
#  'name': ['jack', 'john', 'james'],
#  'grade': ['first', 'second', 'third']}

# %%
#dictionary with multiple values
newdict={1:['red','green','pink'],2:['blue','purple','white'],3:['brown','yellow','orange']}

# %%
newdict
# Out:
# {1: ['red', 'green', 'pink'],
#  2: ['blue', 'purple', 'white'],
#  3: ['brown', 'yellow', 'orange']}

# %%
newdict.keys()
# Out:
# dict_keys([1, 2, 3])

# %%
newdict.values()
# Out:
# dict_values([['red', 'green', 'pink'], ['blue', 'purple', 'white'], ['brown', 'yellow', 'orange']])

# %%
newdict.items()
# Out:
# dict_items([(1, ['red', 'green', 'pink']), (2, ['blue', 'purple', 'white']), (3, ['brown', 'yellow', 'orange'])])

# %%
newdict.clear()

# %%
newdict
# Out:
# {}

# %%
del newdict

# %%
newdict
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_1172/1602567964.py in <module>
# ----> 1 newdict
#
# NameError: name 'newdict' is not defined
