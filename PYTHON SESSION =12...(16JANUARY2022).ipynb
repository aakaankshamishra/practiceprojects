# %% [markdown]
# # MODULES

# %%
#import modulename

# %%
import keyword

# %%
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', '__peg_parser__', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
import sys

# %%
sys.path
# Out:
# ['C:\\Users\\admin',
#  'C:\\ProgramData\\Anaconda3\\python39.zip',
#  'C:\\ProgramData\\Anaconda3\\DLLs',
#  'C:\\ProgramData\\Anaconda3\\lib',
#  'C:\\ProgramData\\Anaconda3',
#  '',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\locket-0.2.1-py3.9.egg',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\win32\\lib',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\Pythonwin',
#  'C:\\ProgramData\\Anaconda3\\lib\\site-packages\\IPython\\extensions',
#  'C:\\Users\\admin\\.ipython']

# %%
import os

# %%
#get current working directory
os.getcwd()
# Out:
# 'C:\\Users\\admin'

# %%
#changing directory
#we can change the current working directory using the chdir() method
#os.chdir('c:\\users')
#os.getcwd()

# %%
#show the list of files and olders in current working directory
os.listdir()
# Out:
# [' python session 1.ipynb',
#  '.conda',
#  '.condarc',
#  '.continuum',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '3D Objects',
#  'AppData',
#  'Application Data',
#  'Contacts',
#  'Cookies',
#  'Desktop',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'IntelGraphicsProfiles',
#  'Links',
#  'Local Settings',
#  'MicrosoftEdgeBackups',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{033303e6-556b-11ec-927a-a0481c117aeb}.TM.blf',
#  'NTUSER.DAT{033303e6-556b-11ec-927a-a0481c117aeb}.TMContainer00000000000000000001.regtrans-ms',
#  'NTUSER.DAT{033303e6-556b-11ec-927a-a0481c117aeb}.TMContainer00000000000000000002.regtrans-ms',
#  'ntuser.ini',
#  'OneDrive',
#  'Pictures',
#  'PrintHood',
#  'python 2 session.......ipynb',
#  'PYTHON 3RD SESSION.ipynb',
#  'python session 1.ipynb',
#  'PYTHON SESSION 10...9JAN 2022.ipynb',
#  'python session 2.ipynb',
#  'python session 4.....ipynb',
# ...

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
#square root
math.sqrt(9)
# Out:
# 3.0

# %%
#power function
math.pow(2,3)
# Out:
# 8.0

# %% [markdown]
# import from remaining
# we can import a module by remaining it as follows

# %%
import math as m
m.pi
# Out:
# 3.141592653589793

# %%
m.pow(4,2)
# Out:
# 16.0

# %%
from math import pi
pi
# Out:
# 3.141592653589793

# %%
from math import sqrt
sqrt(9)
# Out:
# 3.0

# %%
print("the value of pi is",pi)
# Out:
# the value of pi is 3.141592653589793

# %%
math.__dict__.keys()
# Out:
# dict_keys(['__name__', '__doc__', '__package__', '__loader__', '__spec__', 'acos', 'acosh', 'asin', 'asinh', 'atan', 'atan2', 'atanh', 'ceil', 'copysign', 'cos', 'cosh', 'degrees', 'dist', 'erf', 'erfc', 'exp', 'expm1', 'fabs', 'factorial', 'floor', 'fmod', 'frexp', 'fsum', 'gamma', 'gcd', 'hypot', 'isclose', 'isfinite', 'isinf', 'isnan', 'isqrt', 'lcm', 'ldexp', 'lgamma', 'log', 'log1p', 'log10', 'log2', 'modf', 'pow', 'radians', 'remainder', 'sin', 'sinh', 'sqrt', 'tan', 'tanh', 'trunc', 'prod', 'perm', 'comb', 'nextafter', 'ulp', 'pi', 'e', 'tau', 'inf', 'nan'])

# %%
import datetime

# %%
dt=datetime.datetime.now()
dt
# Out:
# datetime.datetime(2022, 1, 17, 19, 44, 17, 505358)

# %% [markdown]
# # GET CURRENT DATE

# %%
dt1=datetime.date.today()
dt1
# Out:
# datetime.date(2022, 1, 17)

# %% [markdown]
# # commonly used classess in datetime module are:
#     date class
#     time class
#     datetime class
#     timedelta class

# %%
import datetime
d=datetime.date(2021,5,25)
d
# Out:
# datetime.date(2021, 5, 25)

# %%
from datetime import date
a=date(2021,5,26)
a
# Out:
# datetime.date(2021, 5, 26)

# %% [markdown]
# we can write directly also

# %%
#get current date
td=date.today()
td
# Out:
# datetime.date(2022, 1, 17)

# %%
print("year=",td.year)
print("month=",td.month)
print("day=",td.day)
# Out:
# year= 2022
# month= 1
# day= 17

# %% [markdown]
# a time object instantiated from the time class represent the local time

# %%
from datetime import time
a=time()
print(a)
# Out:
# 00:00:00

# %%
#time(hour,minute,second)
b=time(11,35,56)
print(b)
# Out:
# 11:35:56

# %%
print("hour:",b.hour)
print("minute:",b.minute)
print("second:",b.second)
# Out:
# hour: 11
# minute: 35
# second: 56

# %%
from datetime import datetime
a=datetime(2021,4,26)
print(a)
# Out:
# 2021-04-26 00:00:00

# %%
print("year=",a.year)
print("month=",a.month)
print("day=",a.day)
# Out:
# year= 2021
# month= 4
# day= 26

# %%
#datetime (year,month,date,hour,minute,second)
b=datetime(2021,2,27,17,30,50)
print(b.year)
print(b.month)
print(b.hour)
print(b.minute)
print(b.second)
# Out:
# 2021
# 2
# 17
# 30
# 50

# %%
a=100
a
# Out:
# 100

# %%
a=100
b=50
a
# Out:
# 100

# %%
a=100
b=50
a
b
# Out:
# 50

# %%
a=100
b=50
print(a)
print(b)
# Out:
# 100
# 50
