# %%
x=input("Enter first number")
# Out:
# Enter first number56

# %%
x
# Out:
# '56'

# %%
type(x)
# Out:
# str

# %%
y=input("Enter second number")
# Out:
# Enter second number89

# %%
y
# Out:
# '89'

# %%
type(y)
# Out:
# str

# %%
x+y
# Out:
# '5689'

# %%
x=int(input("Enter first number"))
# Out:
# Enter first number56

# %%
x
# Out:
# 56

# %%
y=int(input("Enter second number"))
# Out:
# Enter second number45

# %%
y
# Out:
# 45

# %%
x+y
# Out:
# 101

# %%
m=input("Enter any number")
m
# Out:
# Enter any number45
# '45'

# %%
s=input("Enter any number")
s
# Out:
# Enter any number78
# '78'

# %%
int(m)+int(s)
# Out:
# 123

# %% [markdown]
# # boolean operators

# %%
90>20
# Out:
# True

# %%
33>7
# Out:
# True

# %%
85<8
# Out:
# False

# %%
33<6
# Out:
# False

# %% [markdown]
# # COMPARISION OPERATOR

# %%
#COMPARE
39==39
# Out:
# True

# %%
50==50
# Out:
# True

# %%
30==90
# Out:
# False

# %%
90!=80
# Out:
# True

# %%
90!=90
# Out:
# False

# %%
J=44
K=44
J==K
# Out:
# True

# %% [markdown]
# # STRING CONCATENATION

# %%
"Data"+"Science"
# Out:
# 'DataScience'

# %%
"Machine " + "Learning"
# Out:
# 'Machine Learning'

# %%
'45'+'56'
# Out:
# '4556'

# %%
"ABC"+"DEF"
# Out:
# 'ABCDEF'

# %%
"Elon "+"musk "+"CEO "+"TESLA "+"AI "+"car "
# Out:
# 'Elon musk CEO TESLA AI car '

# %%
'SPACE'+ 'TOURISM'
# Out:
# 'SPACETOURISM'

# %%
'MARS'+'ROVER'
# Out:
# 'MARSROVER'

# %%
"INDIA"=="INDIA"
# Out:
# True

# %%
country="INDIA"

# %%
country
# Out:
# 'INDIA'

# %% [markdown]
# # DATA STRUCTURE

# %% [markdown]
# LIST

# %%
list1=[1,2,3,4,5]

# %%
list1
# Out:
# [1, 2, 3, 4, 5]

# %%
list2=[11,66,55,88,99,]

# %%
list2
# Out:
# [11, 66, 55, 88, 99]

# %%
list3=[45.2,68.5,33.5,88.6]

# %%
list3
# Out:
# [45.2, 68.5, 33.5, 88.6]

# %%
list4=['A','B','C','D']

# %%
list4
# Out:
# ['A', 'B', 'C', 'D']

# %%
mixedlist=[23,56,45,12,48,45,'PUNE',44,'DD',True]

# %%
mixedlist
# Out:
# [23, 56, 45, 12, 48, 45, 'PUNE', 44, 'DD', True]

# %% [markdown]
# # INDEXING

# %%
planetlist=["Mercury","venus","Earth","Mars","Jupiter","Saturn","Neptune","Pluto"]

# %%
planetlist
# Out:
# ['Mercury', 'venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Neptune', 'Pluto']

# %%
planetlist[0]
# Out:
# 'Mercury'

# %%
planetlist[1]
# Out:
# 'venus'

# %%
planetlist[2]
# Out:
# 'Earth'

# %%
planetlist[3]
# Out:
# 'Mars'

# %%
planetlist[4]
# Out:
# 'Jupiter'

# %%
planetlist[5]
# Out:
# 'Saturn'

# %%
planetlist[6]
# Out:
# 'Neptune'

# %%
planetlist[7]
# Out:
# 'Pluto'

# %%
planetlist
# Out:
# ['Mercury', 'venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Neptune', 'Pluto']

# %%
planetlist[0:1]
# Out:
# ['Mercury']

# %%
planetlist[0:2]
# Out:
# ['Mercury', 'venus']

# %%
planetlist[0:3]
# Out:
# ['Mercury', 'venus', 'Earth']

# %%
planetlist[0:4]
# Out:
# ['Mercury', 'venus', 'Earth', 'Mars']

# %%
planetlist[0:5]
# Out:
# ['Mercury', 'venus', 'Earth', 'Mars', 'Jupiter']

# %%
planetlist[0:6]
# Out:
# ['Mercury', 'venus', 'Earth', 'Mars', 'Jupiter', 'Saturn']

# %%
planetlist[0:7]
# Out:
# ['Mercury', 'venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Neptune']

# %%
planetlist[1:2]
# Out:
# ['venus']

# %%
planetlist[1:3]
# Out:
# ['venus', 'Earth']

# %%
planetlist[1:4]
# Out:
# ['venus', 'Earth', 'Mars']

# %%
planetlist[2:6]
# Out:
# ['Earth', 'Mars', 'Jupiter', 'Saturn']

# %%
planetlist[2:8]
# Out:
# ['Earth', 'Mars', 'Jupiter', 'Saturn', 'Neptune', 'Pluto']

# %%
planetlist
# Out:
# ['Mercury', 'venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Neptune', 'Pluto']

# %% [markdown]
# negative indexing

# %%
planetlist[-1]
# Out:
# 'Pluto'

# %%
planetlist[-2]
# Out:
# 'Neptune'

# %%
planetlist[-3]
# Out:
# 'Saturn'

# %%
planetlist[-4]
# Out:
# 'Jupiter'

# %%
planetlist[-5]
# Out:
# 'Mars'

# %%
planetlist[-6]
# Out:
# 'Earth'

# %% [markdown]
# negative slicing

# %%
planetlist[-2:-1]
# Out:
# ['Neptune']

# %%
planetlist[-3:-1]
# Out:
# ['Saturn', 'Neptune']

# %%
planetlist[-4:-1]
# Out:
# ['Jupiter', 'Saturn', 'Neptune']

# %%
planetlist[-5:-1]
# Out:
# ['Mars', 'Jupiter', 'Saturn', 'Neptune']

# %%
planetlist[:-1]
# Out:
# ['Mercury', 'venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Neptune']

# %%
planetlist[:]
# Out:
# ['Mercury', 'venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Neptune', 'Pluto']

# %%
planetlist[:-2]
# Out:
# ['Mercury', 'venus', 'Earth', 'Mars', 'Jupiter', 'Saturn']
