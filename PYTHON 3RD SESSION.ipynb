# %% [markdown]
# # LIST

# %%
planetlist=["mercury","venus","earth"]

# %%
planetlist
# Out:
# ['mercury', 'venus', 'earth']

# %%
len(planetlist)
# Out:
# 3

# %%
planetlist.append("mars")

# %%
planetlist
# Out:
# ['mercury', 'venus', 'earth', 'mars']

# %%
planetlist.append("jupiter")

# %%
planetlist
# Out:
# ['mercury', 'venus', 'earth', 'mars', 'jupiter']

# %%
len(planetlist)
# Out:
# 5

# %%
planetlist.sort()

# %%
planetlist
# Out:
# ['earth', 'jupiter', 'mars', 'mercury', 'venus']

# %%
planetlist.reverse()

# %%
planetlist
# Out:
# ['venus', 'mercury', 'mars', 'jupiter', 'earth']

# %%
planetlist.insert(2,"pluto")

# %%
planetlist
# Out:
# ['venus', 'mercury', 'pluto', 'mars', 'jupiter', 'earth']

# %%
numlist=[1,2,3,4,5]

# %%
numlist.append(6)

# %%
numlist
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
planetlist
# Out:
# ['venus', 'mercury', 'pluto', 'mars', 'jupiter', 'earth']

# %%
planetlist[0:]
# Out:
# ['venus', 'mercury', 'pluto', 'mars', 'jupiter', 'earth']

# %%
planetlist.pop()
# Out:
# 'earth'

# %%
planetlist
# Out:
# ['venus', 'mercury', 'pluto', 'mars', 'jupiter']

# %%
planetlist.pop()
# Out:
# 'jupiter'

# %%
planetlist.pop(2)
# Out:
# 'pluto'

# %%
planetlist
# Out:
# ['venus', 'mercury', 'mars']

# %%
planetlist.remove("mars")

# %%
planetlist
# Out:
# ['venus', 'mercury']

# %%
planetlist.clear()

# %%
planetlist
# Out:
# []

# %%
planetlist.append("uranus")

# %%
planetlist
# Out:
# ['uranus']

# %%
del planetlist

# %%
planetlist
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_10408/3676854626.py in <module>
# ----> 1 planetlist
#
# NameError: name 'planetlist' is not defined

# %%
numlist=[1,2,3,4,5,]

# %%
numlist
# Out:
# [1, 2, 3, 4, 5]

# %%
numlist.append(6)

# %%
numlist
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
mobilelist=["samsung","apple","lenovo","nokia"]

# %%
mobilelist
# Out:
# ['samsung', 'apple', 'lenovo', 'nokia']

# %%
mobilelist[0]
# Out:
# 'samsung'

# %%
mobilelist[1]
# Out:
# 'apple'

# %% [markdown]
# property- mutable mean changing

# %%
mobilelist[1]="teslapi"

# %%
mobilelist
# Out:
# ['samsung', 'teslapi', 'lenovo', 'nokia']

# %%
mobilelist[1]
# Out:
# 'teslapi'

# %%
list1=[100,200,300,400]

# %%
list1
# Out:
# [100, 200, 300, 400]

# %%
list1[2]
# Out:
# 300

# %%
list1[2]=645
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11828/239498101.py in <module>
# ----> 1 list1[2]=645
#
# NameError: name 'list1' is not defined

# %%
l1=[1,2,3,4,5]
l1.append([77,88,99])
l1
# Out:
# [1, 2, 3, 4, 5, [77, 88, 99]]

# %%
l1=[1,2,3,4,5]
l1.extend([77,88,99])
l1
# Out:
# [1, 2, 3, 4, 5, 77, 88, 99]

# %%
fruits=["apples","grapes","banana"]
fruits.append(["papaya","kiwi"])

# %%
fruits
# Out:
# ['apples', 'grapes', 'banana', ['papaya', 'kiwi']]

# %%
fruits=["apples","grapes","orange","banana"]
veggies=["corn","kale","mushroom"]
fruits.append(veggies)
fruits
# Out:
# ['apples', 'grapes', 'orange', 'banana', ['corn', 'kale', 'mushroom']]

# %%
fruits.extend(veggies)
fruits
# Out:
# ['apples',
#  'grapes',
#  'orange',
#  'banana',
#  ['corn', 'kale', 'mushroom'],
#  'corn',
#  'kale',
#  'mushroom']

# %% [markdown]
# tuples

# %% [markdown]
# # TUPLES

# %% [markdown]
# tuples are similar to lists, but they are immutable-which means they cannot be changed after creation

# %%
my_tuple=("michael","herman","31","software devloper")

# %%
my_tuple[1]
# Out:
# 'herman'

# %%
tuple1=[1,2,3,4]
tuple2=[5,6,7,8]

# %%
tuple3=tuple1+tuple2

# %%
tuple3
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
# accessing the element
tuple3[2]
# Out:
# 3

# %%
#tuple values cannot be changed after creation, it is immutable
tuple3[2]=85

# %%
tuple3[2]=85

# %% [markdown]
# # list are mutable i.e it can be changed after creation

# %%
x=[4,5,6,7,8]

# %%
x
# Out:
# [4, 5, 6, 7, 8]

# %%
x[0]
# Out:
# 4

# %%
x[1]
# Out:
# 5

# %%
x[1]=72

# %%
x
# Out:
# [4, 72, 6, 7, 8]

# %%
x1=x
x1
# Out:
# [4, 72, 6, 7, 8]

# %% [markdown]
# # DICTIONARY

# %%
d1={'id':1,'name':'john','class':2}

# %%
d1
# Out:
# {'id': 1, 'name': 'john', 'class': 2}

# %%
d1['id']
# Out:
# 1

# %%
d1['name']
# Out:
# 'john'

# %%
d1['class']
# Out:
# 2

# %%
d1.keys()
# Out:
# dict_keys(['id', 'name', 'class'])

# %%
d1.values()
# Out:
# dict_values([1, 'john', 2])

# %%
d1.items()
# Out:
# dict_items([('id', 1), ('name', 'john'), ('class', 2)])

# %%
numdict={1:100,2:200,3:300,4:400,5:500}
numdict
# Out:
# {1: 100, 2: 200, 3: 300, 4: 400, 5: 500}

# %%
numdict[1]
# Out:
# 100

# %%
numdict[2]
# Out:
# 200

# %%
numdict[4]
# Out:
# 400

# %%
numdict.keys()
# Out:
# dict_keys([1, 2, 3, 4, 5])

# %%
numdict.values()
# Out:
# dict_values([100, 200, 300, 400, 500])

# %%
numdict.items()
# Out:
# dict_items([(1, 100), (2, 200), (3, 300), (4, 400), (5, 500)])

# %% [markdown]
#  in dictonary only keys will be there no indexing
